# %%
import ROOT
from IPython.display import display, Math, Latex
import rootnotes
# Out:
# Welcome to JupyROOT 6.10/05

# %%
cd /home/kakw/efake/WG_Analysis/Plotting
# Out:
# /home/kakw/efake/WG_Analysis/Plotting

# %%
# %run  interactiveStackTree.py --baseDir /data/users/kakw/Resonances/LepGamma_Mlpp_testb_elg_2018_08_26/ --samplesConf Modules/Resonance.py --xsFile cross_sections/photon15.py --lumi 35900. --treeName UMDNTuple/EventTree --fileName tree.root
# Out:
# -------------------------------------
#  LOAD CROSS SECTION INFO
# -------------------------------------
# Sample GJets_HT-600ToInf              cross section : 93.380000 pb     N Events : 2463946  sample lumi : 26386.228314      Scale : 1.360558
# Sample WZ3LNLO                        cross section : 5.260000 pb      N Events : 8260201  sample lumi : 1570380.418251    Scale : 0.022861
# Sample WJetsToLNu_HT-800To1200        cross section : 7.484300 pb      N Events : 1544513  sample lumi : 206367.061716     Scale : 0.173962
# Sample WJetsToLNu_HT-600To800         cross section : 16.288000 pb     N Events : 3779141  sample lumi : 232019.953340     Scale : 0.154728
# Sample GJets_HT-100To200              cross section : 9226.000000 pb   N Events : 5131873  sample lumi : 556.240299        Scale : 64.540451
# Sample ResonanceMass2000              cross section : 0.000172 pb      N Events : 50000    sample lumi : 289872165.921251  Scale : 0.000124
# ...

# %%
[s.name for s in samples.samples]
# Out:
# ['SingleElectron',
#  'DYJetsToLL_M-50',
#  'ZGTo2LG',
#  'WGToLNuG-madgraphMLM',
#  'WGToLNuG_PtG-130-madgraphMLM',
#  'WGToLNuG_PtG-500-madgraphMLM',
#  'WGToLNuG-madgraphMLMMTResCut',
#  'WGToLNuG_PtG-130-madgraphMLMMTResCut',
#  'WGToLNuG_PtG-500-madgraphMLMMTResCut',
#  'Data',
#  'Z+jets',
#  'Zgamma',
#  'WgammaLO',
#  'MCBackgroundLO',
#  'EleFakeBackground']

# %% [markdown]
# https://www-zeuthen.desy.de/~middell/_downloads/pyroot.pdf

# %%
ch = samples.get_samples(name="DYJetsToLL_M-50")[0].chain

# %%
ch.GetTree().Print("toponly")
# Out:
# ******************************************************************************
# *Tree    :EventTree : EventTree                                              *
# *Entries :    78583 : Total =       239015245 bytes  File  Size =   57445210 *
# *        :          : Tree compression factor =   4.16                       *
# ******************************************************************************
# branch: isData                     674
#
# branch: eventNumber             235515
#
# branch: lumiSection             135909
#
# branch: runNumber                 2343
#
# branch: bxNumber                  2159
#
# branch: vtx_n                    89420
#
# branch: pu_n                     94730
#
# branch: rho                     278059
#
# branch: truepu_n                 91186
#
# branch: EventWeights            119602
#
# branch: pdf_id1                  81042
#
# branch: pdf_id2                  80894
#
# branch: pdf_x1                  288666
#
# ...

# %%
ch.GetEntries()
# Out:
# 743669L

# %%
ch.GetEntry(100)
# Out:
# 0

# %%
n=0
a=[]
for events in ch:
    n+=1
    a.append(ch.el_n)

# %%
a
# Out:
# []

# %%
ch.el_n
# Out:
# 0

# %%
filename = "/data/users/kakw/Resonances/LepGamma_Mlpp_testb_elg_2018_08_26/DYJetsToLL_M-50_TuneCUETP8M1_13TeV-madgraphMLM-pythia8/Job_0001/tree.root "
ROOT.TFile.Open(filename)
# Out:
# <ROOT.TFile object ("/data/users/kakw/Resonances/LepGamma_Mlpp_testb_elg_2018_08_26/DYJetsToLL_M-50_TuneCUETP8M1_13TeV-madgraphMLM-pythia8/Job_0001/tree.root") at 0x7dc3b80>

# %%
_49.ls()
f= _49
# Out:
# TFile**		/data/users/kakw/Resonances/LepGamma_Mlpp_testb_elg_2018_08_26/DYJetsToLL_M-50_TuneCUETP8M1_13TeV-madgraphMLM-pythia8/Job_0001/tree.root
#  TFile*		/data/users/kakw/Resonances/LepGamma_Mlpp_testb_elg_2018_08_26/DYJetsToLL_M-50_TuneCUETP8M1_13TeV-madgraphMLM-pythia8/Job_0001/tree.root
#   KEY: TDirectoryFile	UMDNTuple;1	UMDNTuple/

# %%
t = f.Get("UMDNTuple/EventTree")

# %%
t.GetEntries()
# Out:
# 72591L

# %%
t.GetEntry(0)
# Out:
# 2429

# %%
t.ph_pt[0]
# Out:
# 28.539295196533203

# %%
# %run colortest.py
# Out:
# Black
# Red
# Green
# Yellow
# Blue
# Purple
# Cyan
# White
# BOLD
# Black
# Red
# Green
# Yellow
# Blue
# Purple
# Cyan
# White
# Underline
# Black
# Red
# Green
# Yellow
# Blue
# Purple
# Cyan
# White
# Background
# Black
# Red
# Green
# Yellow
# Blue
# Purple
# Cyan
# White
# high intensity
# Black
# Red
# Green
# Yellow
# Blue
# Purple
# Cyan
# White
# BOLD high intensity
# Black
# Red
# Green
# Yellow
# Blue
# Purple
# Cyan
# White
# high intensity backgrounds
# Black
# Red
# Green
# Yellow
# Blue
# Purple
# Cyan
# White

# %%
print Cyan, "Hey there" ,Color_Off
# Out:
#  Hey there
